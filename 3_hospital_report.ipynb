# %% [markdown]
# # Hospital report

# %%
# Disable warnings
import warnings
warnings.filterwarnings('ignore')

from IPython.display import Image
import pandas as pd
from utils.stroke_team_reporting import StrokeTeamReporting

# %% [markdown]
# ## Set team
#
# Set team and set up reporting object.

# %%
team = 'Eastbourne District General Hospital'
team_report = StrokeTeamReporting(team)

# %% [markdown]
# ## Descriptive statistics

# %% [markdown]
# ### All admissions

# %%
team_report.descriptive_summary_all
# Out:
#                                    All teams 1Q  All teams median  \
# admissions                               349.00            481.00
# age                                       73.11             74.84
# age > 80                                   0.36              0.41
# male                                       0.51              0.53
# prior_disability                           0.87              1.02
# prior_disability_0-2                       0.78              0.81
# stroke_severity                            6.36              7.29
# onset_known                                0.58              0.68
# onset_to_arrival_time                    151.00            175.00
# onset_within_4hrs                          0.35              0.38
# precise_onset_known                        0.27              0.34
# onset_during_sleep                         0.09              0.14
# arrive_by_ambulance                        0.76              0.79
# call_to_ambulance_arrival_time            17.00             20.00
# ambulance_on_scene_time                   28.00             31.00
# ambulance_travel_to_hospital_time         15.00             17.00
# arrival_to_scan_time                      39.00             53.00
# thrombolysis                               0.09              0.11
# scan_to_thrombolysis_time                 27.00             34.00
# discharge_disability                       2.41              2.72
# discharge_disability_0-2                   0.45              0.52
# discharge_disability_5-6                   0.17              0.20
#
#                                    All teams 3Q  \
# admissions                               614.00
# age                                       75.95
# age > 80                                   0.44
# male                                       0.54
# prior_disability                           1.21
# prior_disability_0-2                       0.84
# stroke_severity                            7.88
# onset_known                                0.75
# onset_to_arrival_time                    219.00
# onset_within_4hrs                          0.43
# precise_onset_known                        0.39
# onset_during_sleep                         0.17
# arrive_by_ambulance                        0.83
# call_to_ambulance_arrival_time            24.00
# ambulance_on_scene_time                   33.00
# ambulance_travel_to_hospital_time         21.00
# arrival_to_scan_time                      66.00
# thrombolysis                               0.13
# scan_to_thrombolysis_time                 40.00
# discharge_disability                       2.89
# discharge_disability_0-2                   0.59
# discharge_disability_5-6                   0.22
#
#                                    Eastbourne District General Hospital
# admissions                                                       427.00
# age                                                               77.49
# age > 80                                                           0.50
# male                                                               0.49
# prior_disability                                                   0.99
# prior_disability_0-2                                               0.81
# stroke_severity                                                    6.78
# onset_known                                                        0.60
# onset_to_arrival_time                                            142.00
# onset_within_4hrs                                                  0.40
# precise_onset_known                                                0.37
# onset_during_sleep                                                 0.14
# arrive_by_ambulance                                                0.85
# call_to_ambulance_arrival_time                                    20.00
# ambulance_on_scene_time                                           32.00
# ambulance_travel_to_hospital_time                                 20.00
# arrival_to_scan_time                                              27.00
# thrombolysis                                                       0.08
# scan_to_thrombolysis_time                                         43.00
# discharge_disability                                               2.96
# discharge_disability_0-2                                           0.42
# discharge_disability_5-6                                           0.23

# %% [markdown]
# ### Arrivals within 4 hours of known onset

# %%
team_report.descriptive_summary_4hrs
# Out:
#                                    All teams 1Q  All teams median  \
# admissions                              138.000            183.00
# age                                      73.300             74.99
# age > 80                                  0.370              0.41
# male                                      0.510              0.53
# prior_disability                          0.870              1.02
# prior_disability_0-2                      0.770              0.81
# stroke_severity                           8.250              9.11
# onset_known                               1.000              1.00
# onset_to_arrival_time                    98.000            104.00
# onset_within_4hrs                         1.000              1.00
# precise_onset_known                       0.530              0.65
# onset_during_sleep                        0.010              0.03
# arrive_by_ambulance                       0.880              0.91
# call_to_ambulance_arrival_time           15.625             18.00
# ambulance_on_scene_time                  25.625             28.00
# ambulance_travel_to_hospital_time        14.000             16.00
# arrival_to_scan_time                     22.000             28.00
# thrombolysis                              0.250              0.28
# scan_to_thrombolysis_time                27.000             34.00
# discharge_disability                      2.610              2.85
# discharge_disability_0-2                  0.420              0.49
# discharge_disability_5-6                  0.210              0.23
#
#                                    All teams 3Q  \
# admissions                               239.00
# age                                       75.98
# age > 80                                   0.45
# male                                       0.54
# prior_disability                           1.20
# prior_disability_0-2                       0.83
# stroke_severity                            9.63
# onset_known                                1.00
# onset_to_arrival_time                    110.00
# onset_within_4hrs                          1.00
# precise_onset_known                        0.73
# onset_during_sleep                         0.06
# arrive_by_ambulance                        0.93
# call_to_ambulance_arrival_time            21.00
# ambulance_on_scene_time                   30.50
# ambulance_travel_to_hospital_time         20.00
# arrival_to_scan_time                      35.00
# thrombolysis                               0.33
# scan_to_thrombolysis_time                 40.00
# discharge_disability                       3.04
# discharge_disability_0-2                   0.54
# discharge_disability_5-6                   0.26
#
#                                    Eastbourne District General Hospital
# admissions                                                       172.00
# age                                                               77.68
# age > 80                                                           0.51
# male                                                               0.48
# prior_disability                                                   1.02
# prior_disability_0-2                                               0.79
# stroke_severity                                                    8.25
# onset_known                                                        1.00
# onset_to_arrival_time                                            102.00
# onset_within_4hrs                                                  1.00
# precise_onset_known                                                0.72
# onset_during_sleep                                                 0.03
# arrive_by_ambulance                                                0.92
# call_to_ambulance_arrival_time                                    16.00
# ambulance_on_scene_time                                           28.00
# ambulance_travel_to_hospital_time                                 19.00
# arrival_to_scan_time                                              22.00
# thrombolysis                                                       0.19
# scan_to_thrombolysis_time                                         43.00
# discharge_disability                                               3.08
# discharge_disability_0-2                                           0.40
# discharge_disability_5-6                                           0.27

# %% [markdown]
# ## Show overall improvement possible

# %%
figure = team_report.plot_improvement()

# %% [markdown]
# ## Show how thrombolysis decisions compare to 25 benchmark hospitals
#
#
#
# *Benchmark* hospitals are those 25 hospitals most likely to give most thrombolysis if all hospitals saw the same patients up to (and including) time of scan. These are chosen by looking at the machine leraning model and how the stroke team ID affects the odds of receiving thrombolysis (the stroke team *SHAP* value).
#
# An *ideally thrombolysable patient*:
#
# * Infarction
# * 90 mins onset to arrival
# * Onset not during sleep
# * Precise onset time
# * NIHSS 15
# * No prior disability
# * No use of anticoagulants for atrial fibrillation
# * Age 72
#
# *Non-ideal* changes:
#
# * *Late*: Arrival at 3hr 45 min after stroke
# * *Mild stroke*: NIHSS 3
# * *Prior disability*: mRS 3 before stroke
# * *Imprecise*: Imprecisely known stroke onset time
# * *Age*: Age 87

# %%
team_report.show_prototype_patients()

# %% [markdown]
# To Do
#
# Proportion of arrivals in 30 min bins?
