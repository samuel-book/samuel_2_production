# %% [markdown]
# # Hospital report

# %%
# Disable warnings
import warnings
warnings.filterwarnings('ignore')

from IPython.display import Image
import pandas as pd
from utils.stroke_team_reporting import StrokeTeamReporting

# %% [markdown]
# ## Set team
#
# Set team and set up reporting object.

# %%
team = 'Royal Preston Hospital'
team_report = StrokeTeamReporting(team)

# %% [markdown]
# ## Descriptive statistics

# %% [markdown]
# ### All admissions

# %%
team_report.descriptive_summary_all
# Out:
#                                    All teams 1Q  All teams median  \
# admissions                               349.00            481.00
# age                                       73.11             74.84
# age > 80                                   0.36              0.41
# male                                       0.51              0.53
# prior_disability                           0.87              1.02
# prior_disability_0-2                       0.78              0.81
# stroke_severity                            6.36              7.29
# onset_known                                0.58              0.68
# onset_to_arrival_time                    151.00            175.00
# onset_within_4hrs                          0.35              0.38
# precise_onset_known                        0.27              0.34
# onset_during_sleep                         0.09              0.14
# arrive_by_ambulance                        0.76              0.79
# call_to_ambulance_arrival_time            17.00             20.00
# ambulance_on_scene_time                   28.00             31.00
# ambulance_travel_to_hospital_time         15.00             17.00
# arrival_to_scan_time                      39.00             53.00
# thrombolysis                               0.09              0.11
# scan_to_thrombolysis_time                 27.00             34.00
# discharge_disability                       2.41              2.72
# discharge_disability_0-2                   0.45              0.52
# discharge_disability_5-6                   0.17              0.20
#
#                                    All teams 3Q  Royal Preston Hospital
# admissions                               614.00                  462.00
# age                                       75.95                   73.64
# age > 80                                   0.44                    0.38
# male                                       0.54                    0.53
# prior_disability                           1.21                    1.02
# prior_disability_0-2                       0.84                    0.80
# stroke_severity                            7.88                    6.68
# onset_known                                0.75                    0.62
# onset_to_arrival_time                    219.00                  203.00
# onset_within_4hrs                          0.43                    0.35
# precise_onset_known                        0.39                    0.30
# onset_during_sleep                         0.17                    0.12
# arrive_by_ambulance                        0.83                    0.74
# call_to_ambulance_arrival_time            24.00                   23.00
# ambulance_on_scene_time                   33.00                   26.50
# ambulance_travel_to_hospital_time         21.00                   20.50
# arrival_to_scan_time                      66.00                   62.00
# thrombolysis                               0.13                    0.07
# scan_to_thrombolysis_time                 40.00                   40.00
# discharge_disability                       2.89                    2.41
# discharge_disability_0-2                   0.59                    0.60
# discharge_disability_5-6                   0.22                    0.22

# %% [markdown]
# ### Arrivals within 4 hours of known onset

# %%
team_report.descriptive_summary_4hrs.round(2)
# Out:
#                                    All teams 1Q  All teams median  \
# admissions                               138.00            183.00
# age                                       73.30             74.99
# age > 80                                   0.37              0.41
# male                                       0.51              0.53
# prior_disability                           0.87              1.02
# prior_disability_0-2                       0.77              0.81
# stroke_severity                            8.25              9.11
# onset_known                                1.00              1.00
# onset_to_arrival_time                     98.00            104.00
# onset_within_4hrs                          1.00              1.00
# precise_onset_known                        0.53              0.65
# onset_during_sleep                         0.01              0.03
# arrive_by_ambulance                        0.88              0.91
# call_to_ambulance_arrival_time            15.62             18.00
# ambulance_on_scene_time                   25.62             28.00
# ambulance_travel_to_hospital_time         14.00             16.00
# arrival_to_scan_time                      22.00             28.00
# thrombolysis                               0.25              0.28
# scan_to_thrombolysis_time                 27.00             34.00
# discharge_disability                       2.61              2.85
# discharge_disability_0-2                   0.42              0.49
# discharge_disability_5-6                   0.21              0.23
#
#                                    All teams 3Q  Royal Preston Hospital
# admissions                               239.00                  160.00
# age                                       75.98                   74.53
# age > 80                                   0.45                    0.41
# male                                       0.54                    0.51
# prior_disability                           1.20                    1.11
# prior_disability_0-2                       0.83                    0.78
# stroke_severity                            9.63                    9.11
# onset_known                                1.00                    1.00
# onset_to_arrival_time                    110.00                  100.00
# onset_within_4hrs                          1.00                    1.00
# precise_onset_known                        0.73                    0.65
# onset_during_sleep                         0.06                    0.01
# arrive_by_ambulance                        0.93                    0.90
# call_to_ambulance_arrival_time            21.00                   20.00
# ambulance_on_scene_time                   30.50                   22.00
# ambulance_travel_to_hospital_time         20.00                   20.00
# arrival_to_scan_time                      35.00                   32.50
# thrombolysis                               0.33                    0.20
# scan_to_thrombolysis_time                 40.00                   40.00
# discharge_disability                       3.04                    2.72
# discharge_disability_0-2                   0.54                    0.54
# discharge_disability_5-6                   0.26                    0.29

# %% [markdown]
# ## Show overall improvement possible

# %%
figure = team_report.plot_improvement()

# %% [markdown]
# ## Show how thrombolysis decisions compare to 25 benchmark hospitals
#
#
#
# *Benchmark* hospitals are those 25 hospitals most likely to give most thrombolysis if all hospitals saw the same patients up to (and including) time of scan. These are chosen by looking at the machine leraning model and how the stroke team ID affects the odds of receiving thrombolysis (the stroke team *SHAP* value).
#
# An *ideally thrombolysable patient*:
#
# * Infarction
# * 90 mins onset to arrival
# * Onset not during sleep
# * Precise onset time
# * NIHSS 15
# * No prior disability
# * No use of anticoagulants for atrial fibrillation
# * Age 72
#
# *Non-ideal* changes:
#
# * *Late*: Arrival at 3hr 45 min after stroke
# * *Mild stroke*: NIHSS 3
# * *Prior disability*: mRS 3 before stroke
# * *Imprecise*: Imprecisely known stroke onset time
# * *Age*: Age 87

# %%
team_report.show_prototype_patients()

# %% [markdown]
# To Do
#
# Proportion of arrivals in 30 min bins?
